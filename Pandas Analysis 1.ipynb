# %%
# %run 3.ipynb
import datetime

# %%
D = pd.read_excel(r"data_akbilgic.xlsx")
# Out:
# M:\Anaconda\Lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
D
# Out:
#               Unnamed: 0  TL BASED USD BASED    imkb_x Unnamed: 4 Unnamed: 5  \
# 0                   date       ISE       ISE        SP        DAX       FTSE
# 1    2009-01-05 00:00:00  0.035754  0.038376 -0.004679   0.002193   0.003894
# 2    2009-01-06 00:00:00  0.025426  0.031813  0.007787   0.008455   0.012866
# 3    2009-01-07 00:00:00 -0.028862 -0.026353 -0.030469  -0.017833  -0.028735
# 4    2009-01-08 00:00:00 -0.062208 -0.084716  0.003391  -0.011726  -0.000466
# ..                   ...       ...       ...       ...        ...        ...
# 532  2011-02-16 00:00:00  0.008599    0.0134  0.006238   0.001925   0.007952
# 533  2011-02-17 00:00:00   0.00931  0.015977  0.003071  -0.001186   0.000345
# 534  2011-02-18 00:00:00  0.000191 -0.001653  0.001923   0.002872  -0.000723
# 535  2011-02-21 00:00:00 -0.013069 -0.013706 -0.020742  -0.014239  -0.011275
# 536  2011-02-22 00:00:00 -0.007246 -0.019442         0  -0.000473  -0.002997
#
# ...

# %%
df=pd.DataFrame(D)

# %%
df
# Out:
#               Unnamed: 0  TL BASED USD BASED    imkb_x Unnamed: 4 Unnamed: 5  \
# 0                   date       ISE       ISE        SP        DAX       FTSE
# 1    2009-01-05 00:00:00  0.035754  0.038376 -0.004679   0.002193   0.003894
# 2    2009-01-06 00:00:00  0.025426  0.031813  0.007787   0.008455   0.012866
# 3    2009-01-07 00:00:00 -0.028862 -0.026353 -0.030469  -0.017833  -0.028735
# 4    2009-01-08 00:00:00 -0.062208 -0.084716  0.003391  -0.011726  -0.000466
# ..                   ...       ...       ...       ...        ...        ...
# 532  2011-02-16 00:00:00  0.008599    0.0134  0.006238   0.001925   0.007952
# 533  2011-02-17 00:00:00   0.00931  0.015977  0.003071  -0.001186   0.000345
# 534  2011-02-18 00:00:00  0.000191 -0.001653  0.001923   0.002872  -0.000723
# 535  2011-02-21 00:00:00 -0.013069 -0.013706 -0.020742  -0.014239  -0.011275
# 536  2011-02-22 00:00:00 -0.007246 -0.019442         0  -0.000473  -0.002997
#
# ...

# %%
df.columns = [c.replace(' ', '_') for c in df.columns]

# %%
df
# Out:
#               Unnamed:_0  TL_BASED USD_BASED    imkb_x Unnamed:_4 Unnamed:_5  \
# 0                   date       ISE       ISE        SP        DAX       FTSE
# 1    2009-01-05 00:00:00  0.035754  0.038376 -0.004679   0.002193   0.003894
# 2    2009-01-06 00:00:00  0.025426  0.031813  0.007787   0.008455   0.012866
# 3    2009-01-07 00:00:00 -0.028862 -0.026353 -0.030469  -0.017833  -0.028735
# 4    2009-01-08 00:00:00 -0.062208 -0.084716  0.003391  -0.011726  -0.000466
# ..                   ...       ...       ...       ...        ...        ...
# 532  2011-02-16 00:00:00  0.008599    0.0134  0.006238   0.001925   0.007952
# 533  2011-02-17 00:00:00   0.00931  0.015977  0.003071  -0.001186   0.000345
# 534  2011-02-18 00:00:00  0.000191 -0.001653  0.001923   0.002872  -0.000723
# 535  2011-02-21 00:00:00 -0.013069 -0.013706 -0.020742  -0.014239  -0.011275
# 536  2011-02-22 00:00:00 -0.007246 -0.019442         0  -0.000473  -0.002997
#
# ...

# %%
df.TL_BASED
# Out:
# 0           ISE
# 1      0.035754
# 2      0.025426
# 3     -0.028862
# 4     -0.062208
#          ...
# 532    0.008599
# 533     0.00931
# 534    0.000191
# 535   -0.013069
# 536   -0.007246
# Name: TL_BASED, Length: 537, dtype: object

# %%
df.TL_BASED[0]="ISE1"

# %%
df
# Out:
#               Unnamed:_0  TL_BASED USD_BASED    imkb_x Unnamed:_4 Unnamed:_5  \
# 0                   date      ISE1       ISE        SP        DAX       FTSE
# 1    2009-01-05 00:00:00  0.035754  0.038376 -0.004679   0.002193   0.003894
# 2    2009-01-06 00:00:00  0.025426  0.031813  0.007787   0.008455   0.012866
# 3    2009-01-07 00:00:00 -0.028862 -0.026353 -0.030469  -0.017833  -0.028735
# 4    2009-01-08 00:00:00 -0.062208 -0.084716  0.003391  -0.011726  -0.000466
# ..                   ...       ...       ...       ...        ...        ...
# 532  2011-02-16 00:00:00  0.008599    0.0134  0.006238   0.001925   0.007952
# 533  2011-02-17 00:00:00   0.00931  0.015977  0.003071  -0.001186   0.000345
# 534  2011-02-18 00:00:00  0.000191 -0.001653  0.001923   0.002872  -0.000723
# 535  2011-02-21 00:00:00 -0.013069 -0.013706 -0.020742  -0.014239  -0.011275
# 536  2011-02-22 00:00:00 -0.007246 -0.019442         0  -0.000473  -0.002997
#
# ...

# %%
 df.columns = df.iloc[0]

# %%
df
# Out:
# 0                   date      ISE1       ISE        SP       DAX      FTSE  \
# 0                   date      ISE1       ISE        SP       DAX      FTSE
# 1    2009-01-05 00:00:00  0.035754  0.038376 -0.004679  0.002193  0.003894
# 2    2009-01-06 00:00:00  0.025426  0.031813  0.007787  0.008455  0.012866
# 3    2009-01-07 00:00:00 -0.028862 -0.026353 -0.030469 -0.017833 -0.028735
# 4    2009-01-08 00:00:00 -0.062208 -0.084716  0.003391 -0.011726 -0.000466
# ..                   ...       ...       ...       ...       ...       ...
# 532  2011-02-16 00:00:00  0.008599    0.0134  0.006238  0.001925  0.007952
# 533  2011-02-17 00:00:00   0.00931  0.015977  0.003071 -0.001186  0.000345
# 534  2011-02-18 00:00:00  0.000191 -0.001653  0.001923  0.002872 -0.000723
# 535  2011-02-21 00:00:00 -0.013069 -0.013706 -0.020742 -0.014239 -0.011275
# 536  2011-02-22 00:00:00 -0.007246 -0.019442         0 -0.000473 -0.002997
#
# 0      NIKKEI   BOVESPA        EU        EM
# ...

# %%
df = df.drop([0])

# %%
df
# Out:
# 0                   date      ISE1       ISE        SP       DAX      FTSE  \
# 1    2009-01-05 00:00:00  0.035754  0.038376 -0.004679  0.002193  0.003894
# 2    2009-01-06 00:00:00  0.025426  0.031813  0.007787  0.008455  0.012866
# 3    2009-01-07 00:00:00 -0.028862 -0.026353 -0.030469 -0.017833 -0.028735
# 4    2009-01-08 00:00:00 -0.062208 -0.084716  0.003391 -0.011726 -0.000466
# 5    2009-01-09 00:00:00   0.00986  0.009658 -0.021533 -0.019873  -0.01271
# ..                   ...       ...       ...       ...       ...       ...
# 532  2011-02-16 00:00:00  0.008599    0.0134  0.006238  0.001925  0.007952
# 533  2011-02-17 00:00:00   0.00931  0.015977  0.003071 -0.001186  0.000345
# 534  2011-02-18 00:00:00  0.000191 -0.001653  0.001923  0.002872 -0.000723
# 535  2011-02-21 00:00:00 -0.013069 -0.013706 -0.020742 -0.014239 -0.011275
# 536  2011-02-22 00:00:00 -0.007246 -0.019442         0 -0.000473 -0.002997
#
# 0      NIKKEI   BOVESPA        EU        EM
# ...

# %%
for i in df.ISE1:
    i = float(i)

# %%
for i in df.ISE:
    i = float(i)

# %%
for i in df.SP:
    i = float(i)

# %%
for i in df.DAX:
    i = float(i)

# %%
for i in df.FTSE:
    i = float(i)

# %%
for i in df.NIKKEI:
    i = float(i)

# %%
for i in df.BOVESPA:
    i = float(i)

# %%
for i in df.EU:
    i = float(i)

# %%
for i in df.EM:
    i = float(i)

# %%
df
# Out:
# 0                   date      ISE1       ISE        SP       DAX      FTSE  \
# 1    2009-01-05 00:00:00  0.035754  0.038376 -0.004679  0.002193  0.003894
# 2    2009-01-06 00:00:00  0.025426  0.031813  0.007787  0.008455  0.012866
# 3    2009-01-07 00:00:00 -0.028862 -0.026353 -0.030469 -0.017833 -0.028735
# 4    2009-01-08 00:00:00 -0.062208 -0.084716  0.003391 -0.011726 -0.000466
# 5    2009-01-09 00:00:00   0.00986  0.009658 -0.021533 -0.019873  -0.01271
# ..                   ...       ...       ...       ...       ...       ...
# 532  2011-02-16 00:00:00  0.008599    0.0134  0.006238  0.001925  0.007952
# 533  2011-02-17 00:00:00   0.00931  0.015977  0.003071 -0.001186  0.000345
# 534  2011-02-18 00:00:00  0.000191 -0.001653  0.001923  0.002872 -0.000723
# 535  2011-02-21 00:00:00 -0.013069 -0.013706 -0.020742 -0.014239 -0.011275
# 536  2011-02-22 00:00:00 -0.007246 -0.019442         0 -0.000473 -0.002997
#
# 0      NIKKEI   BOVESPA        EU        EM
# ...

# %%
counts=df.groupby('ISE1').size()
print (counts.head())
# Out:
# ISE1
# -0.062208    1
# -0.056753    1
# -0.045389    1
# -0.043092    1
# -0.041168    1
# dtype: int64

# %%
counts=df.groupby('ISE1').size()
print (counts)
# Out:
# ISE1
# -0.062208    1
# -0.056753    1
# -0.045389    1
# -0.043092    1
# -0.041168    1
#             ..
#  0.045220    1
#  0.046831    1
#  0.047239    1
#  0.051980    1
#  0.068952    1
# Length: 536, dtype: int64

# %%
c=df[(df.SP > 0) & (df.FTSE<0) ]

# %%
c
# Out:
# 0                   date      ISE1       ISE        SP       DAX      FTSE  \
# 4    2009-01-08 00:00:00 -0.062208 -0.084716  0.003391 -0.011726 -0.000466
# 7    2009-01-13 00:00:00  0.015445 -0.000272  0.001757 -0.017674 -0.006141
# 9    2009-01-15 00:00:00  0.000662 -0.017268  0.001328 -0.019551 -0.014335
# 13   2009-01-21 00:00:00  0.000865  0.001529  0.042572  0.005011 -0.007729
# 17   2009-01-27 00:00:00 -0.006635  0.010949  0.010866 -0.000798 -0.003475
# ..                   ...       ...       ...       ...       ...       ...
# 520  2011-01-31 00:00:00  0.001056 -0.008883  0.007633 -0.003571  -0.00315
# 523  2011-02-03 00:00:00 -0.024478  -0.02785  0.002351  0.001392 -0.002804
# 528  2011-02-10 00:00:00 -0.017664 -0.024921  0.000749  0.002644 -0.005351
# 530  2011-02-14 00:00:00 -0.002498  0.000405  0.002382  0.003444 -0.000462
# 534  2011-02-18 00:00:00  0.000191 -0.001653  0.001923  0.002872 -0.000723
#
# 0      NIKKEI   BOVESPA        EU        EM
# ...

# %%
d=df

# %%
e=df.drop(columns=['date'])

# %%
e
# Out:
# 0        ISE1       ISE        SP       DAX      FTSE    NIKKEI   BOVESPA  \
# 1    0.035754  0.038376 -0.004679  0.002193  0.003894         0   0.03119
# 2    0.025426  0.031813  0.007787  0.008455  0.012866  0.004162   0.01892
# 3   -0.028862 -0.026353 -0.030469 -0.017833 -0.028735  0.017293 -0.035899
# 4   -0.062208 -0.084716  0.003391 -0.011726 -0.000466 -0.040061  0.028283
# 5     0.00986  0.009658 -0.021533 -0.019873  -0.01271 -0.004474 -0.009764
# ..        ...       ...       ...       ...       ...       ...       ...
# 532  0.008599    0.0134  0.006238  0.001925  0.007952  0.005717  0.018371
# 533   0.00931  0.015977  0.003071 -0.001186  0.000345   0.00262  0.001686
# 534  0.000191 -0.001653  0.001923  0.002872 -0.000723  0.000568  0.005628
# 535 -0.013069 -0.013706 -0.020742 -0.014239 -0.011275  0.001358 -0.011942
# 536 -0.007246 -0.019442         0 -0.000473 -0.002997  -0.01792 -0.012252
#
# 0          EU        EM
# 1    0.012698  0.028524
# 2    0.011341  0.008773
# ...

# %%
c=e[(df.SP > 0) & (df.FTSE<0) ]

# %%
plt.hist(c)
# Out:
# (array([[ 0.,  1.,  0.,  3.,  4., 29., 42., 12.,  0.,  1.],
#         [ 1.,  0.,  2.,  2.,  8., 30., 37., 10.,  1.,  1.],
#         [ 0.,  0.,  0.,  0.,  0.,  0., 71., 17.,  2.,  2.],
#         [ 0.,  0.,  0.,  0.,  3., 31., 57.,  1.,  0.,  0.],
#         [ 0.,  0.,  0.,  0.,  4., 36., 52.,  0.,  0.,  0.],
#         [ 0.,  0.,  1.,  2., 11., 26., 30., 16.,  4.,  2.],
#         [ 0.,  0.,  0.,  0.,  1., 15., 49., 20.,  5.,  2.],
#         [ 0.,  0.,  0.,  0.,  2., 33., 57.,  0.,  0.,  0.],
#         [ 0.,  0.,  0.,  0.,  4., 25., 56.,  7.,  0.,  0.]]),
#  array([-0.0847159 , -0.0714295 , -0.05814309, -0.04485669, -0.03157028,
#         -0.01828388, -0.00499747,  0.00828893,  0.02157534,  0.03486174,
#          0.04814815]),
#  <a list of 9 BarContainer objects>)

# %%
plt.pie(abs(df.SP))
plt.show()

# %%
counts=df.groupby('ISE1').size()
k = counts.head(10)

# %%
plt.pie(abs(k))
plt.show()

# %%
plt.pie?
dw=['a','b','c','d','e','f','g','h','i','j']

# %%
plt.pie(abs(k),labels=dw)
plt.show()

# %%
counts=df.groupby('ISE1').size()

# %%
df
# Out:
# 0                   date      ISE1       ISE        SP       DAX      FTSE  \
# 1    2009-01-05 00:00:00  0.035754  0.038376 -0.004679  0.002193  0.003894
# 2    2009-01-06 00:00:00  0.025426  0.031813  0.007787  0.008455  0.012866
# 3    2009-01-07 00:00:00 -0.028862 -0.026353 -0.030469 -0.017833 -0.028735
# 4    2009-01-08 00:00:00 -0.062208 -0.084716  0.003391 -0.011726 -0.000466
# 5    2009-01-09 00:00:00   0.00986  0.009658 -0.021533 -0.019873  -0.01271
# ..                   ...       ...       ...       ...       ...       ...
# 532  2011-02-16 00:00:00  0.008599    0.0134  0.006238  0.001925  0.007952
# 533  2011-02-17 00:00:00   0.00931  0.015977  0.003071 -0.001186  0.000345
# 534  2011-02-18 00:00:00  0.000191 -0.001653  0.001923  0.002872 -0.000723
# 535  2011-02-21 00:00:00 -0.013069 -0.013706 -0.020742 -0.014239 -0.011275
# 536  2011-02-22 00:00:00 -0.007246 -0.019442         0 -0.000473 -0.002997
#
# 0      NIKKEI   BOVESPA        EU        EM
# ...

# %%
df.plot('ISE','SP')
# Out:
# <Axes: xlabel='ISE'>

# %%
skewn(ml2_age)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 skewn(ml2_age)
#
# NameError: name 'ml2_age' is not defined
