# %%
from numpy import genfromtxt
from sklearn. model_selection import train_test_split
import matplotlib .pyplot as plt
from mpl_toolkits .mplot3d import Axes3D
import numpy as np
import pandas as pd

# %%
pa = pd.read_csv("pricerunner_aggregate.csv")
pa=pa[0:10000]
train,test = train_test_split(pa,test_size= 0.3)

# %%
pa
# Out:
#       ProductID                                       ProductTitle  \
# 0             1                    apple iphone 8 plus 64gb silver
# 1             2                apple iphone 8 plus 64 gb spacegrau
# 2             3  apple mq8n2b/a iphone 8 plus 64gb 5.5 12mp sim...
# 3             4                apple iphone 8 plus 64gb space grey
# 4             5  apple iphone 8 plus gold 5.5 64gb 4g unlocked ...
# ...         ...                                                ...
# 9995      16340  hp intel xeon quad core l5506 2.13ghz 60 watts...
# 9996      16341  hp intel xeon quad core l5506 2.13ghz 60 watts...
# 9997      16342  hp intel xeon l5506 fio kit 2.13ghz 4mb l3 pro...
# 9998      16343  hp intel xeon l5506 fio kit 2.13ghz 4mb l3 pro...
# 9999      16344  hp intel xeon l5506 fio kit 2.13ghz 4mb l3 pro...
#
#        MerchantID   ClusterID  \
# 0               1           1
# 1               2           1
# 2               3           1
# 3               4           1
# ...

# %%
pa.columns
# Out:
# Index(['ProductID', 'ProductTitle', ' MerchantID', ' ClusterID',
#        ' ClusterLabel', ' CategoryID', 'CategoryLabel'],
#       dtype='object')

# %%
X_train = train[['ProductID',' MerchantID',' ClusterID',' CategoryID']]
y_train = train.CategoryLabel
X_test = test[['ProductID',' MerchantID',' ClusterID',' CategoryID']]
y_test = test.CategoryLabel

# %%
from sklearn.metrics import accuracy_score
import sklearn. discriminant_analysis as DA
from sklearn. naive_bayes import GaussianNB
from sklearn. neighbors import KNeighborsClassifier
from sklearn. linear_model import LogisticRegression
from sklearn.svm import SVC

# %%
names = ["Logit","NBayes", "LDA", "QDA", "KNN", "SVM"]
classifiers = [ LogisticRegression (C=1e4, max_iter=1000000),
               GaussianNB (),
                DA. LinearDiscriminantAnalysis (),
                DA. QuadraticDiscriminantAnalysis (),
                KNeighborsClassifier ( n_neighbors =5),
                SVC()]

print('Name Accuracy\n'+14*'-')

for name , clf in zip(names , classifiers ):
    clf.fit(X_train , y_train)
    y_pred = clf.predict(X_test)
    print('{:6} {:3.3f}'.format(name , accuracy_score (y_test ,y_pred)))
# Out:
# Name Accuracy
# --------------
# Logit  1.000
# NBayes 1.000
# LDA    0.974
# QDA    0.241
# KNN    1.000
# SVM    0.996
# M:\Anaconda\Lib\site-packages\sklearn\discriminant_analysis.py:935: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# M:\Anaconda\Lib\site-packages\sklearn\discriminant_analysis.py:960: RuntimeWarning: divide by zero encountered in power
#   X2 = np.dot(Xm, R * (S ** (-0.5)))
# M:\Anaconda\Lib\site-packages\sklearn\discriminant_analysis.py:960: RuntimeWarning: invalid value encountered in multiply
#   X2 = np.dot(Xm, R * (S ** (-0.5)))
# M:\Anaconda\Lib\site-packages\sklearn\discriminant_analysis.py:963: RuntimeWarning: divide by zero encountered in log
#   u = np.asarray([np.sum(np.log(s)) for s in self.scalings_])
